# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hydra import compose, initialize

from falldet.schemas import InferenceConfig

with initialize(version_base=None, config_path="../config"):
    cfg = compose(config_name="inference_config", overrides=["data.size=768", "num_frames=9"])
    cfg = InferenceConfig.model_validate(cfg)
    print(cfg)

# %%
import logging

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from falldet.data.video_dataset_factory import get_video_datasets
from falldet.plot import (
    compute_publication_figsize,
    set_publication_rc_defaults,
    visualize_video,
)

logger = logging.getLogger(__name__)
logging.basicConfig(
    level=logging.DEBUG, format="%(asctime)s - %(levelname)s - %(message)s", force=True
)
logging.getLogger("matplotlib").setLevel(logging.WARNING)
logging.getLogger("seaborn").setLevel(logging.WARNING)

_, (w, h) = set_publication_rc_defaults(height_ratio=0.7)


dataset = get_video_datasets(
    cfg, mode=cfg.data.mode, split=cfg.data.split, seed=cfg.data.seed, size=cfg.data.size
)
dataset = dataset.datasets[0]

# %%
df = pd.DataFrame(dataset.video_segments)

print(f"Total segments: {len(df)}")
print(f"Unique videos:  {df['video_path'].nunique()}")
print(f"Unique labels:  {df['label_str'].nunique()}")
print("\nDuration stats (seconds):")
print(df["duration"].describe().round(2))

# %%
label_order = df["label_str"].value_counts().index
figsize = compute_publication_figsize(width_fraction=1, height_ratio=0.5)
fig, ax = plt.subplots(figsize=figsize)
sns.countplot(data=df, y="label_str", order=label_order, ax=ax, palette="Blues_r")

for container in ax.containers:
    ax.bar_label(container, padding=3, fontsize=8)

ax.set_xlabel("Count")
ax.set_ylabel("")
fig.tight_layout()
fig.savefig("../outputs/plots/segment_label_distribution.pdf", bbox_inches="tight")
plt.show()

# %%
counts = df["label_str"].value_counts().reindex(label_order)

figsize = compute_publication_figsize(width_fraction=1, height_ratio=0.6)
fig, ax = plt.subplots(figsize=figsize)

cmap = plt.cm.Blues_r
colors = cmap(pd.Series(range(len(counts))) / max(len(counts) - 1, 1))

# add boxes around bars

bars = ax.barh(counts.index, counts.values, color=colors, edgecolor="black", linewidth=0.5)

ax.bar_label(bars, padding=3, fontsize=8)
ax.set_xlabel("Count")
ax.set_ylabel("")
ax.invert_yaxis()

fig.tight_layout()
fig.savefig("../outputs/plots/segment_label_distribution_matplotlib.pdf", bbox_inches="tight")
plt.show()

# %%
figsize

# %%
df_seq = df.copy()
df_seq["row_order"] = range(len(df_seq))

order_cols = [
    col
    for col in [
        "segment_index",
        "segment_idx",
        "clip_idx",
        "start_time",
        "start",
        "start_sec",
        "start_frame",
    ]
    if col in df_seq.columns
]

sort_cols = ["video_path"] + (order_cols if order_cols else ["row_order"])
df_seq = df_seq.sort_values(sort_cols).copy()

df_seq["label_norm"] = df_seq["label_str"].astype(str).str.strip().str.lower()
df_seq["prev_label_norm"] = df_seq.groupby("video_path")["label_norm"].shift(1)

is_jump = df_seq["label_norm"].eq("jump")
jump_after_fall = is_jump & df_seq["prev_label_norm"].eq("fall")

n_jump = int(is_jump.sum())
n_jump_after_fall = int(jump_after_fall.sum())
pct_jump_after_fall = 100 * n_jump_after_fall / n_jump if n_jump else 0.0

print(f"Ordering used: {sort_cols}")
print(f"Jump segments: {n_jump}")
print(f"Jump segments immediately following a fall: {n_jump_after_fall}")
print(f"Percentage: {pct_jump_after_fall:.2f}%")

# %%
df_seq

# %%
transition_counts = (
    df_seq.loc[df_seq["prev_label_norm"].notna(), ["prev_label_norm", "label_norm"]]
    .value_counts()
    .rename("count")
    .reset_index()
    .rename(columns={"prev_label_norm": "from_label", "label_norm": "to_label"})
)

transition_counts["share_of_from"] = transition_counts["count"] / transition_counts.groupby(
    "from_label"
)["count"].transform("sum")
transition_counts["transition"] = (
    transition_counts["from_label"] + " $\\rightarrow$ " + transition_counts["to_label"]
)

top_transitions = transition_counts.head(20).copy()

display(
    top_transitions[["transition", "count", "share_of_from"]]
    .rename(columns={"share_of_from": "share_from_source"})
    .style.format({"share_from_source": "{:.1%}"})
)

transition_label_order = df_seq["label_norm"].value_counts().index
transition_matrix = transition_counts.pivot(
    index="from_label", columns="to_label", values="count"
).reindex(index=transition_label_order, columns=transition_label_order, fill_value=0)

fig, axes = plt.subplots(
    1,
    2,
    figsize=(18, 8),
    gridspec_kw={"width_ratios": [1.0, 1.4]},
)

sns.barplot(data=top_transitions, y="transition", x="count", ax=axes[0], color="steelblue")
axes[0].set_title("Most Frequent Consecutive Segment Pairs")
axes[0].set_xlabel("Count")
axes[0].set_ylabel("Transition")

sns.heatmap(transition_matrix, cmap="Blues", ax=axes[1], cbar_kws={"label": "Count"})
axes[1].set_title("Consecutive Segment Transition Matrix")
axes[1].set_xlabel("Next segment")
axes[1].set_ylabel("Previous segment")

fig.tight_layout()
plt.show()

# %%
mean_dur = df["duration"].mean()
median_dur = df["duration"].median()

fig, ax = plt.subplots(figsize=(8, 4))
sns.histplot(data=df, x="duration", bins=50, kde=False, ax=ax, color="steelblue", log_scale=True)

ax.axvline(mean_dur, color="tomato", linestyle="--", label=f"Mean: {mean_dur:.1f}s")
ax.axvline(median_dur, color="orange", linestyle="-.", label=f"Median: {median_dur:.1f}s")

ax.set_xlabel("Duration (seconds)")
ax.set_ylabel("Count")
ax.set_title("Segment Duration Distribution")
ax.legend()
fig.tight_layout()
plt.show()

# %%
sns.histplot(
    df.query("label_str in ['fall', 'fallen', 'jump']"),
    x="duration",
    hue="label_str",
    multiple="stack",
)

# %%
# plot cumulative distribution of segment durations
fig, ax = plt.subplots(figsize=(8, 4))
sns.ecdfplot(data=df, x="duration", ax=ax)
ax.set_xlabel("Duration (seconds)")

df.duration.quantile([0.9, 0.95, 0.975, 0.99])

# %%
label_order

# %%
figsize = compute_publication_figsize(width_fraction=1, height_ratio=0.666)
fig, ax = plt.subplots(figsize=figsize)

df_filtered = df.query("duration < 12")
box_data = [
    df_filtered.loc[df_filtered["label_str"] == lbl, "duration"].values for lbl in label_order
]

bp = ax.boxplot(
    box_data[::-1],
    vert=False,
    tick_labels=label_order[::-1],
    patch_artist=True,
    flierprops=dict(marker="o", markersize=3, alpha=0.5),
)

cmap = plt.cm.Blues
colors = [cmap(i / len(label_order)) for i in range(len(label_order))]
for patch, color in zip(bp["boxes"], colors):
    patch.set_facecolor(color)

# cleaner label
ax.set_xlabel("Duration (s)")
ax.set_ylabel("")
fig.tight_layout()
plt.savefig("../outputs/plots/segment_duration_by_label.pdf", bbox_inches="tight")

# %%
g = sns.catplot(
    df.query("duration < 12"),
    x="duration",
    y="label_str",
    kind="box",
    aspect=1.3,
    height=4,
    order=label_order,
    palette="Blues_r",
)
g.despine(left=False, bottom=False)
g.ax.set_xlabel("Duration (seconds)")
g.ax.set_ylabel("")
plt.grid("off")

# plot veritcal lines for mean and median
median_dur = df["duration"].median()
plt.savefig("../outputs/plots/segment_duration_boxplot.pdf", bbox_inches="tight")
# g.ax.axvline(mean_dur, color="tomato", linestyle="--", label=f"Mean: {mean_dur:.1f}s")

# %%
df.iloc[0]

# %%
df.iloc[:3]

# %%
idx = 0
fig, ax = visualize_video(idx=idx, dataset=dataset)
fig.savefig(f"../outputs/plots/example_segment_{idx}.pdf", bbox_inches="tight")

# %%
frames = dataset[1640]
